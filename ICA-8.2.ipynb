# %% [markdown]
# # In-class Assignment 8.2
#
# **Week 8 Wednesday**

# %% [markdown]
# #### &#x2705; Stephanie, Alex, Cy

# %% [markdown]
# ---
#
# ## Part 1: Continuing ICA 8.1
#
# We'll start by picking up our work from ICA 8.1. In that assignment, you must:
# - &#x2705; Access and load the data set from `~/hub_data_share/data/MuRun2010B.csv`.
#     - Details about the variables in the data set are provided here: https://opendata.cern.ch/record/700
# - &#x2705; Filter the data set based on the events that represent the decay products of a single parent particle.
# - &#x2705; Compute the invariant mass of each collision.
# - &#x2705; Create histograms to view the distribution of invariant masses.
# - &#x2705; Identify the peaks that could represent the detection of a parent particle.
#
# In the code below, the first task has been provided for you.

# %%
import pandas as pd

df = pd.read_csv("../data/MuRun2010B.csv", skiprows=5)

df.head()
# Out:
#       Run     Event Type1        E1      px1       py1       pz1      pt1  \
# 0  146436  90830792     G  19.17120  3.817130  9.04323 -16.46730  9.81583
# 1  146436  90862225     G  12.94350  5.125790 -3.98369 -11.19730  6.49180
# 2  146436  90644850     G  12.39990 -0.849742  9.40110   8.04015  9.43943
# 3  146436  90678594     G  17.81320 -1.959590  2.80531  17.48110  3.42195
# 4  146436  90686690     G   7.95664  7.097000 -1.31646   3.34613  7.21806
#
#        eta1      phi1  Q1 Type2        E2       px2       py2       pz2  \
# 0 -1.289420  1.171390   1     T   5.43984 -0.362592  2.626990 -4.748490
# 1 -1.313350 -0.660674  -1     G  11.86360  4.789840 -6.262220 -8.864340
# 2  0.772580  1.660940   1     G   8.55532 -4.851550  6.976960 -0.983229
# 3  2.333500  2.180530   1     G   9.42174  4.365230  0.168017  8.347130
# 4  0.448399 -0.183411   1     T   5.44467 -1.341760  1.386470  5.090250
#
#        pt2      eta2      phi2  Q2
# 0  2.65189 -1.345870  1.707960   1
# ...

# %% [markdown]
# &#9989; Complete the remaining tasks listed from ICA 8.1, and create visualizations that focus on each possible identification of a parent particle from this data set.
#
# For each visualization, you aren't expected to know the exact parent particle, but discuss with your group why you think a parent particle could be identified.

# %% [markdown]
# ---
#
# ## Part 2: Work on Project Proposals
#
# You submitted a group project proposal on Canvas. Take some class time to:
# - Make sure you have a clearly defined physics phenomenon to shape your project around.
# - Make sure you a few milestones clearly stated. Each milestone is meant to serve as a place where you'll have some progress to show, but it's not the full solution yet.
# - Brainstorm some options for expanding your project further. Sometimes the solution ends up being easier than we think. It's good to have ideas of where you could go further or deeper into the computation model.
#
# &#9989; Document your discussion of these bullet points, and resubmit your answers to the project proposal assignment on Canvas.
